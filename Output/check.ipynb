# %%
import pandas as pd
pd.read_csv("UI.csv")
# Out:
#                                                  link  \
# 0   https://www.simplyhired.com/job/PHR8X9FDonQkGr...
# 1   https://www.simplyhired.com/job/Dga7k6g044mN0s...
# 2   https://www.simplyhired.com/job/7qoTnw3ZzOxEpq...
# 3   https://www.simplyhired.com/job/KyB0n3syTXzY04...
# 4   https://www.simplyhired.com/job/lbPdlw6s5YSQ8B...
# 5   https://www.simplyhired.com/job/UYG7VUi0idtK2d...
# 6   https://www.simplyhired.com/job/Zm9SN-DckTFfNa...
# 7   https://www.simplyhired.com/job/rsKH8M6oGfTLHj...
# 8   https://www.simplyhired.com/job/Aq9xz4eom6grQG...
# 9   https://www.simplyhired.com/job/CdOjfuNC_hNGfS...
# 10  https://www.simplyhired.com/job/II6UFti6DxVbs9...
# 11  https://www.simplyhired.com/job/6VSXKlv-HQSan3...
# 12  https://www.simplyhired.com/job/kr0G-jpKmuFA2G...
# 13  https://www.simplyhired.com/job/xEpY2yuepbXkMF...
# 14  https://www.simplyhired.com/job/e6igEuyLQVs0jv...
# 15  https://www.simplyhired.com/job/FQcRNLWjLma0Kk...
# ...

# %%
pd.read_csv("ML.csv")
# Out:
#                                                  link  \
# 0   https://www.simplyhired.com/job/mlUANjTUfHPu0x...
# 1   https://www.simplyhired.com/job/kQ-8evQO2ljZAh...
# 2   https://www.simplyhired.com/job/gUSe_vbnleYNZD...
# 3   https://www.simplyhired.com/job/ZVPdig26ghGHXp...
# 4   https://www.simplyhired.com/job/WJ-GNXxSyLG6BY...
# 5   https://www.simplyhired.com/job/Pq3CjWcYSPnyNz...
# 6   https://www.simplyhired.com/job/GeRdfyCV2XDcrm...
# 7   https://www.simplyhired.com/job/sRoKl30dFw4R-O...
# 8   https://www.simplyhired.com/job/IU1NzBCuS0nnDs...
# 9   https://www.simplyhired.com/job/I8Gwqei8IxX4Kv...
# 10  https://www.simplyhired.com/job/JUnvaf4yFgkyjZ...
# 11  https://www.simplyhired.com/job/A7YPvY5lyIIsc3...
# 12  https://www.simplyhired.com/job/lQVDl2m0e1Cg21...
# 13  https://www.simplyhired.com/job/DsBltrPZlMXULY...
# 14  https://www.simplyhired.com/job/5SSl3DX_GwsOVU...
# 15  https://www.simplyhired.com/job/KZyKvhBe2UWRx9...
# ...
